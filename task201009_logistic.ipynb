# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression

# %%
wine = pd.read_csv('wine.csv')
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
data = wine.drop('label', axis=1)
label = wine['label']
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.4, stratify=label, random_state=10)

# %%
params = {'C': [1e-3, 1e-2, 0.1, 1, 10, 1e2, 1e3]}

clf = GridSearchCV(LogisticRegression(), params, cv=4)
clf.fit(X_train, y_train)
res = pd.DataFrame(clf.cv_results_)
# Out:
# /usr/local/var/pyenv/versions/3.7.6/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/var/pyenv/versions/3.7.6/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
res.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0       0.024124      0.003910         0.001682        0.000070   0.001
# 1       0.022225      0.001387         0.001550        0.000091    0.01
# 2       0.022589      0.002378         0.001543        0.000192     0.1
# 3       0.020849      0.001351         0.001477        0.000075       1
# 4       0.020762      0.001539         0.001477        0.000148      10
#
#          params  split0_test_score  split1_test_score  split2_test_score  \
# 0  {'C': 0.001}           0.703704           0.703704           0.692308
# 1   {'C': 0.01}           0.925926           0.740741           0.923077
# 2    {'C': 0.1}           0.851852           0.851852           1.000000
# 3      {'C': 1}           0.888889           0.851852           1.000000
# 4     {'C': 10}           0.851852           0.888889           1.000000
#
#    split3_test_score  mean_test_score  std_test_score  rank_test_score
# ...

# %%
res.sort_values('rank_test_score').head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 5       0.023661      0.002237         0.001636        0.000186     100
# 3       0.020849      0.001351         0.001477        0.000075       1
# 4       0.020762      0.001539         0.001477        0.000148      10
# 2       0.022589      0.002378         0.001543        0.000192     0.1
# 6       0.019972      0.000843         0.001324        0.000008    1000
#
#           params  split0_test_score  split1_test_score  split2_test_score  \
# 5   {'C': 100.0}           0.888889           0.925926                1.0
# 3       {'C': 1}           0.888889           0.851852                1.0
# 4      {'C': 10}           0.851852           0.888889                1.0
# 2     {'C': 0.1}           0.851852           0.851852                1.0
# 6  {'C': 1000.0}           0.888889           0.851852                1.0
#
#    split3_test_score  mean_test_score  std_test_score  rank_test_score
# ...

# %%
params = {'C': [1, 10, 40, 70, 100, 150, 200, 300, 400, 500]}

clf = GridSearchCV(LogisticRegression(), params, cv=4)
clf.fit(X_train, y_train)
res = pd.DataFrame(clf.cv_results_)
# Out:
# /usr/local/var/pyenv/versions/3.7.6/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/var/pyenv/versions/3.7.6/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
res.sort_values('rank_test_score').head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 4       0.024501      0.002263         0.001781        0.000377     100
# 5       0.022947      0.002368         0.001532        0.000194     150
# 8       0.023907      0.001665         0.001537        0.000058     400
# 0       0.023666      0.002651         0.001509        0.000099       1
# 1       0.022526      0.002823         0.001429        0.000077      10
#
#        params  split0_test_score  split1_test_score  split2_test_score  \
# 4  {'C': 100}           0.888889           0.925926                1.0
# 5  {'C': 150}           0.888889           0.925926                1.0
# 8  {'C': 400}           0.888889           0.925926                1.0
# 0    {'C': 1}           0.888889           0.851852                1.0
# 1   {'C': 10}           0.851852           0.888889                1.0
#
#    split3_test_score  mean_test_score  std_test_score  rank_test_score
# ...

# %%
clf = LogisticRegression(C=100)
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# /usr/local/var/pyenv/versions/3.7.6/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.9583333333333334

# %%
coeff = pd.DataFrame([X_train.columns, clf.coef_[0]]).T
coeff
# Out:
#                                0           1
# 0                        alcohol    0.540835
# 1                     malic_acid    0.384732
# 2                            ash    0.350047
# 3              alcalinity_of_ash   -0.701475
# 4                      magnesium  -0.0620499
# 5                  total_phenols    0.608142
# 6                     flavanoids     1.05103
# 7           nonflavanoid_phenols  -0.0891857
# 8                proanthocyanins    0.115335
# 9                color_intensity    0.188478
# 10                           hue   0.0387245
# 11  od280/od315_of_diluted_wines    0.837972
# 12                       proline  0.00814016

# %%
pd.DataFrame([X_train.columns, clf.coef_[0]])
# Out:
#           0           1         2                  3          4  \
# 0   alcohol  malic_acid       ash  alcalinity_of_ash  magnesium
# 1  0.540835    0.384732  0.350047          -0.701475 -0.0620499
#
#                5           6                     7                8  \
# 0  total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins
# 1       0.608142     1.05103            -0.0891857         0.115335
#
#                  9         10                            11          12
# 0  color_intensity        hue  od280/od315_of_diluted_wines     proline
# 1         0.188478  0.0387245                      0.837972  0.00814016

# %%
from matplotlib import pyplot as plt

scores = []
for i in range(100):
    X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.4, stratify=label, random_state=i)
    clf = LogisticRegression(C=100)
    clf.fit(X_train, y_train)
    scores.append(clf.score(X_test, y_test))
plt.hist(scores, alpha=0.5)
plt.show()
# Out:
# /usr/local/var/pyenv/versions/3.7.6/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/var/pyenv/versions/3.7.6/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:764: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
